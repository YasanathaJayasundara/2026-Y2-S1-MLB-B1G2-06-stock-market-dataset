# %% [markdown]
# # Integrated Group Preprocessing Pipeline
#
# **Group ID:** `[ADD GROUP ID]`
# **Dataset:** `data/raw/Market.csv`
#
# Combine only tested work from the six individual notebooks in the sections below.

# %% [markdown]
# ## 1. Imports and data loading

# %%
# Add shared imports and load data/raw/Market.csv here.

# %% [markdown]
# ## 2. Missing-data handling and validation — Member 1

# %%
# Add the verified Member 1 preprocessing code here.

# %% [markdown]
# ## 3. Categorical encoding — Member 2

# %%
# Add the verified Member 2 encoding code here.

# %% [markdown]
# ## 4. Outlier handling — Member 3

# %%
# Add the verified Member 3 outlier-handling code here.

# %% [markdown]
# ## 5. Feature scaling — Member 4

# %%
# Add the verified Member 4 scaling code here.

# %% [markdown]
# ## 6. Feature engineering — Member 5

# %%
# Add the verified Member 5 feature-engineering code here.

# %% [markdown]
# ## 7. Feature selection — Member 6

# %%
# Add the verified Member 6 feature-selection code here.

# %% [markdown]
# ## 8. Chronological split, EDA outputs, saving, and final validation

# %%
# Add the chronological train/validation/test split.
# Generate shared EDA figures and save outputs/logs.
# Add final assertions so the complete pipeline can be run from top to bottom.
